# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from config3 import api_key

# incorportated citypy to determine city based on latitude and longitude
from citipy import citipy

# range of latitude and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # if the city is unique, then add it to our cities list
    if city not in cities:
        cities.append(city)
        
# print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # API limit so it does not exceed call rate
        time.sleep(1.0)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Meiganga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1de0df34e03dff405ad894b167b42bc&q=meiganga
# Processing Record 2 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1de0df34e03dff405ad894b167b42bc&q=clyde river
# Processing Record 3 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1de0df34e03dff405ad894b167b42bc&q=east london
# Processing Record 4 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1de0df34e03dff405ad894b167b42bc&q=kapaa
# Processing Record 5 | Contamana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1de0df34e03dff405ad894b167b42bc&q=contamana
# Processing Record 6 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1de0df34e03dff405ad894b167b42bc&q=rikitea
# Processing Record 7 | Kaitangata
# ...

# %%
weather_dict = {
    "City": city_name,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Latitude": lat,
    "Longitude": lng,
    "Max Temperature": max_temp,
    "Wind Speed": wind_speed
}

# %%
weather_df = pd.DataFrame(weather_dict)
weather_df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity  Latitude  Longitude  \
# 0     Meiganga         100      CM  1567041320        95      6.52      14.29
# 1  Clyde River           1      CA  1567041322        71     70.47     -68.59
# 2  East London          25      ZA  1567041323        81    -33.02      27.91
# 3        Kapaa          40      US  1567041324        62     22.08    -159.32
# 4    Contamana          80      PE  1567041326        69     -7.35     -75.01
#
#    Max Temperature  Wind Speed
# 0            64.67        3.27
# 1            50.00        3.36
# 2            46.67        4.72
# 3            87.80       10.29
# 4            78.35        2.57

# %%
weather_df.to_csv("cities1.csv")

# %%
weather_df.count()
# Out:
# City               556
# Cloudiness         556
# Country            556
# Date               556
# Humidity           556
# Latitude           556
# Longitude          556
# Max Temperature    556
# Wind Speed         556
# dtype: int64

# %%
plt.scatter(weather_df["Latitude"], weather_df["Max Temperature"], edgecolors="black", facecolors="skyblue")
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the Figure
plt.savefig("Max_Temp_vs_Latitude.png")

# show plot
plt.show()

# %%
plt.scatter(weather_df["Latitude"], weather_df["Humidity"], edgecolors="black", facecolors="skyblue")
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# save the figure
plt.savefig("latitude_vs_humidity.png")

# show plot
plt.show()

# %%
plt.scatter(weather_df["Latitude"], weather_df["Cloudiness"], edgecolors="black", facecolors="skyblue")
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# save the figure
plt.savefig("latitude_vs_cloudiness.png")

# show plot
plt.show()

# %%
plt.scatter(weather_df["Latitude"], weather_df["Wind Speed"], edgecolors="black", facecolors="skyblue")
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# save the fig
plt.savefig("latitude_vs_wind_speed.png")

# show plot 
plt.show()
